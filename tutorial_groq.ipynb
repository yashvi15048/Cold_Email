# %%
pip install langchain_groq
# Out:
# Requirement already satisfied: langchain_groq in c:\users\yasha\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\yasha\anaconda3\lib\site-packages (from langchain_groq) (0.3.46)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\yasha\anaconda3\lib\site-packages (from langchain_groq) (0.20.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\yasha\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\yasha\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yasha\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\yasha\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\yasha\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\yasha\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (4.11.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\yasha\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_groq) (0.3.18)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\yasha\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_groq) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\yasha\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\yasha\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_groq) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\yasha\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_groq) (24.1)
# Requirement already satisfied: idna>=2.8 in c:\users\yasha\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (3.7)
# Requirement already satisfied: certifi in c:\users\yasha\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\yasha\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\yasha\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\yasha\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain_groq) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\yasha\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain_groq) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\yasha\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain_groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\yasha\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain_groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\yasha\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain_groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\yasha\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\yasha\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yasha\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain_groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yasha\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.45->langchain_groq) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.3-70b-versatile"
)

response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[2], line 9
#       1 from langchain_groq import ChatGroq
#       3 llm = ChatGroq(
#       4     temperature=0,
#       5     groq_api_key='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',
#       6     model_name="llama-3.1-70b-versatile"
#       7 )
# ----> 9 response = llm.invoke("The first person to land on moon was ...")
#      10 print(response.content)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:307, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     296 def invoke(
#     297     self,
#     298     input: LanguageModelInput,
#    (...)
#     302     **kwargs: Any,
#     303 ) -> BaseMessage:
#     304     config = ensure_config(config)
#     305     return cast(
#     306         ChatGeneration,
# --> 307         self.generate_prompt(
#     308             [self._convert_input(input)],
#     309             stop=stop,
#     310             callbacks=config.get("callbacks"),
#     311             tags=config.get("tags"),
#     312             metadata=config.get("metadata"),
#     313             run_name=config.get("run_name"),
#     314             run_id=config.pop("run_id", None),
#     315             **kwargs,
#     316         ).generations[0][0],
#     317     ).message
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:843, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     835 def generate_prompt(
#     836     self,
#     837     prompts: list[PromptValue],
#    (...)
#     840     **kwargs: Any,
#     841 ) -> LLMResult:
#     842     prompt_messages = [p.to_messages() for p in prompts]
# --> 843     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:683, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     680 for i, m in enumerate(messages):
#     681     try:
#     682         results.append(
# --> 683             self._generate_with_cache(
#     684                 m,
#     685                 stop=stop,
#     686                 run_manager=run_managers[i] if run_managers else None,
#     687                 **kwargs,
#     688             )
#     689         )
#     690     except BaseException as e:
#     691         if run_managers:
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:908, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     906 else:
#     907     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 908         result = self._generate(
#     909             messages, stop=stop, run_manager=run_manager, **kwargs
#     910         )
#     911     else:
#     912         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\langchain_groq\chat_models.py:480, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     475 message_dicts, params = self._create_message_dicts(messages, stop)
#     476 params = {
#     477     **params,
#     478     **kwargs,
#     479 }
# --> 480 response = self.client.create(messages=message_dicts, **params)
#     481 return self._create_chat_result(response)
#
# File ~\anaconda3\Lib\site-packages\groq\resources\chat\completions.py:322, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, reasoning_format, response_format, seed, service_tier, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     166 def create(
#     167     self,
#     168     *,
#    (...)
#     198     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     199 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     200     """
#     201     Creates a model response for the given chat conversation.
#     202
#    (...)
#     320       timeout: Override the client-level default timeout for this request, in seconds
#     321     """
# --> 322     return self._post(
#     323         "/openai/v1/chat/completions",
#     324         body=maybe_transform(
#     325             {
#     326                 "messages": messages,
#     327                 "model": model,
#     328                 "frequency_penalty": frequency_penalty,
#     329                 "function_call": function_call,
#     330                 "functions": functions,
#     331                 "logit_bias": logit_bias,
#     332                 "logprobs": logprobs,
#     333                 "max_completion_tokens": max_completion_tokens,
#     334                 "max_tokens": max_tokens,
#     335                 "n": n,
#     336                 "parallel_tool_calls": parallel_tool_calls,
#     337                 "presence_penalty": presence_penalty,
#     338                 "reasoning_format": reasoning_format,
#     339                 "response_format": response_format,
#     340                 "seed": seed,
#     341                 "service_tier": service_tier,
#     342                 "stop": stop,
#     343                 "stream": stream,
#     344                 "temperature": temperature,
#     345                 "tool_choice": tool_choice,
#     346                 "tools": tools,
#     347                 "top_logprobs": top_logprobs,
#     348                 "top_p": top_p,
#     349                 "user": user,
#     350             },
#     351             completion_create_params.CompletionCreateParams,
#     352         ),
#     353         options=make_request_options(
#     354             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     355         ),
#     356         cast_to=ChatCompletion,
#     357         stream=stream or False,
#     358         stream_cls=Stream[ChatCompletionChunk],
#     359     )
#
# File ~\anaconda3\Lib\site-packages\groq\_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\Lib\site-packages\groq\_base_client.py:917, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     914 else:
#     915     retries_taken = 0
# --> 917 return self._request(
#     918     cast_to=cast_to,
#     919     options=options,
#     920     stream=stream,
#     921     stream_cls=stream_cls,
#     922     retries_taken=retries_taken,
#     923 )
#
# File ~\anaconda3\Lib\site-packages\groq\_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1028     retries_taken=retries_taken,
#    1029 )
#
# BadRequestError: Error code: 400 - {'error': {'message': 'The model `llama-3.1-70b-versatile` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
